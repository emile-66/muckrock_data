# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from io import StringIO
from datetime import timedelta

#prevents warnings from being printed
import warnings
warnings.filterwarnings('ignore')

# %%
sd = pd.read_csv('sd_requests.csv')
sd = sd.convert_dtypes()
sd.head()
# Out:
#         id  status                                               desc  \
# 0  15-1810  CLOSED  Notices of Violation/Notice to Comply, fire in...
# 1  15-1811  CLOSED       The October 2015 monthly report for SeaWorld
# 2  15-1812  CLOSED  Records related to the following BIDS:  Adams ...
# 3  15-1813  CLOSED  Historical lease payments made by SeaWorld to ...
# 4  15-1814  CLOSED  Open violations, variances, ordinances, approv...
#
#                        date                                             depts  \
# 0  December 7, 2015 via web                                  Code Enforcement
# 1  December 7, 2015 via web  Department of Real Estate and Airport Management
# 2  December 7, 2015 via web                                        City Clerk
# 3  December 7, 2015 via web  Department of Real Estate and Airport Management
# 4  December 7, 2015 via web                                  Code Enforcement
#
#                                                 docs                 poc  \
# 0  title,link
# 5040 ShorehamPlace building permits...    Ginger Rodriguez
# 1                                               <NA>     Jeffrey Wallace
# 2  title,link
# http://www.sandiego.gov/park-and-re...  Mailei Ross-Cerezo
# 3                                               <NA>     Jeffrey Wallace
# 4  title,link
# Site Plan - 11943 El Camino Real.pd...    Ginger Rodriguez
#
#                                                 msgs
# 0  title,item,time
# "Request Closed
# Public",02. Re...
# 1  title,item,time
# "Request Published
# Public",,"D...
# 2  title,item,time
# "Request Closed
# Public",Still ...
# 3  title,item,time
# "Request Closed
# Public",02. Re...
# 4  title,item,time
# "Request Closed
# Public",02. Re...

# %%
sd.shape
# Out:
# (28848, 8)

# %%
sd = sd.rename(columns = {'date': 'request date'})
sd = sd.fillna('')

sd['city'] = 'San Diego'
sd['state'] = 'CA'

# %%
csv_to_df = lambda csv: pd.read_csv(StringIO(csv)) if csv else None
sd['docs_csv'] = sd['docs'].apply(csv_to_df)
sd['msgs_csv'] = sd['msgs'].apply(csv_to_df)

sd['docs_csv'] = sd['docs_csv'].apply(lambda df: df.convert_dtypes().fillna('') if df is not None else None)
sd['msgs_csv'] = sd['msgs_csv'].apply(lambda df: df.convert_dtypes().fillna('') if df is not None else None)

# %%
sd['num docs'] = sd['docs_csv'].map(lambda df: len(df) if df is not None else 0)
sd.head()
# Out:
#         id  status                                               desc  \
# 0  15-1810  CLOSED  Notices of Violation/Notice to Comply, fire in...
# 1  15-1811  CLOSED       The October 2015 monthly report for SeaWorld
# 2  15-1812  CLOSED  Records related to the following BIDS:  Adams ...
# 3  15-1813  CLOSED  Historical lease payments made by SeaWorld to ...
# 4  15-1814  CLOSED  Open violations, variances, ordinances, approv...
#
#   request date                                             depts  \
# 0   2015-12-07                                  Code Enforcement
# 1   2015-12-07  Department of Real Estate and Airport Management
# 2   2015-12-07                                        City Clerk
# 3   2015-12-07  Department of Real Estate and Airport Management
# 4   2015-12-07                                  Code Enforcement
#
#                                                 docs                 poc  \
# 0  title,link
# 5040 ShorehamPlace building permits...    Ginger Rodriguez
# 1                                                        Jeffrey Wallace
# 2  title,link
# http://www.sandiego.gov/park-and-re...  Mailei Ross-Cerezo
# 3                                                        Jeffrey Wallace
# 4  title,link
# Site Plan - 11943 El Camino Real.pd...    Ginger Rodriguez
#
#                                                 msgs       city state  \
# 0  title,item,time
# "Request Closed
# Public",02. Re...  San Diego    CA
# 1  title,item,time
# "Request Published
# Public",,"D...  San Diego    CA
# 2  title,item,time
# "Request Closed
# Public",Still ...  San Diego    CA
# 3  title,item,time
# "Request Closed
# Public",02. Re...  San Diego    CA
# 4  title,item,time
# "Request Closed
# Public",02. Re...  San Diego    CA
#
#                                             docs_csv  \
# 0                                       title  \
# ...
# 1                                               None
# 2                                                ...
# 3                                               None
# 4                                    title  \
# 0  ...
#
#                                             msgs_csv  num docs
# 0                            title               ...         2
# 1                            title               ...         0
# 2                            title  \
# 0         R...         1
# 3                            title               ...         0
# 4                             title              ...         2

# %%
sd['request date'] = sd['request date'].str.extract(r'([A-z][a-z]+\s+\d{1,2},\s+\d{4})')
sd['request date'] = pd.to_datetime(sd['request date'], infer_datetime_format=True)

# %%
sd.head()
# Out:
#         id  status                                               desc  \
# 0  15-1810  CLOSED  Notices of Violation/Notice to Comply, fire in...
# 1  15-1811  CLOSED       The October 2015 monthly report for SeaWorld
# 2  15-1812  CLOSED  Records related to the following BIDS:  Adams ...
# 3  15-1813  CLOSED  Historical lease payments made by SeaWorld to ...
# 4  15-1814  CLOSED  Open violations, variances, ordinances, approv...
#
#   request date                                             depts  \
# 0   2015-12-07                                  Code Enforcement
# 1   2015-12-07  Department of Real Estate and Airport Management
# 2   2015-12-07                                        City Clerk
# 3   2015-12-07  Department of Real Estate and Airport Management
# 4   2015-12-07                                  Code Enforcement
#
#                                                 docs                 poc  \
# 0  title,link
# 5040 ShorehamPlace building permits...    Ginger Rodriguez
# 1                                                        Jeffrey Wallace
# 2  title,link
# http://www.sandiego.gov/park-and-re...  Mailei Ross-Cerezo
# 3                                                        Jeffrey Wallace
# 4  title,link
# Site Plan - 11943 El Camino Real.pd...    Ginger Rodriguez
#
#                                                 msgs       city state  \
# 0  title,item,time
# "Request Closed
# Public",02. Re...  San Diego    CA
# 1  title,item,time
# "Request Published
# Public",,"D...  San Diego    CA
# 2  title,item,time
# "Request Closed
# Public",Still ...  San Diego    CA
# 3  title,item,time
# "Request Closed
# Public",02. Re...  San Diego    CA
# 4  title,item,time
# "Request Closed
# Public",02. Re...  San Diego    CA
#
#                                             docs_csv  \
# 0                                       title  \
# ...
# 1                                               None
# 2                                                ...
# 3                                               None
# 4                                    title  \
# 0  ...
#
#                                             msgs_csv  num docs
# 0                            title               ...         2
# 1                            title               ...         0
# 2                            title  \
# 0         R...         1
# 3                            title               ...         0
# 4                             title              ...         2

# %%
#number of open and closed requests for san diego
pd.value_counts(sd['status'])
# Out:
# CLOSED    28843
# OPEN          5
# Name: status, dtype: Int64

# %%
#pd.Series(sd['depts'].unique()).to_frame().to_csv('unique sd depts.csv')

# %%
dept_count = sd.groupby('depts').count().reset_index()
dept_count = dept_count[['depts', 'id']].rename(columns = {'id': 'requests received'})
dept_count
# Out:
#                                                  depts  requests received
# 0                                                                     143
# 1                       ADA Compliance & Accessibility                  6
# 2                                             Airports                 41
# 3                                      Animal Services                849
# 4                    Assistant Chief Operating Officer                  4
# ..                                                 ...                ...
# 469            Transportation, Performance & Analytics                  6
# 470      Transportation, Public Records Administration                 21
# 471  Transportation, Public Records Administration ...                  1
# 472                         Transportation, Stormwater                  1
# 473                                     Urban Division                  7
#
# [474 rows x 2 columns]

# %%
tb1 = sd.loc[4]['msgs_csv']
tb1.head()
# Out:
#                          title                                  item  \
# 0        Request Closed
# Public                          02. Released
# 1  Document(s) Released
# Public  Site Plan - 11943 El Camino Real.pdf
# 2      Request Reopened
# Public
# 3        Request Closed
# Public                          02. Released
# 4  Document(s) Released
# Public           15-1814 Fire Responsive.pdf
#
#                                              time
# 0  December 24, 2015, 10:34am by Ginger Rodriquez
# 1  December 24, 2015, 10:33am by Ginger Rodriquez
# 2  December 24, 2015, 10:32am by Ginger Rodriquez
# 3   December 24, 2015, 8:09am by Ginger Rodriquez
# 4   December 24, 2015, 8:09am by Ginger Rodriquez

# %%
d = {0: True, -1: False}
tb1[tb1['title'].str.find('Request Closed').map(d)]
# Out:
#                    title          item  \
# 0  Request Closed
# Public  02. Released
# 3  Request Closed
# Public  02. Released
# 6  Request Closed
# Public  02. Released
# 8  Request Closed
# Public  02. Released
# 9  Request Closed
# Public  02. Released
#
#                                              time
# 0  December 24, 2015, 10:34am by Ginger Rodriquez
# 3   December 24, 2015, 8:09am by Ginger Rodriquez
# 6   December 17, 2015, 4:00pm by Ginger Rodriquez
# 8   December 17, 2015, 3:54pm by Ginger Rodriquez
# 9   December 17, 2015, 3:52pm by Ginger Rodriquez
